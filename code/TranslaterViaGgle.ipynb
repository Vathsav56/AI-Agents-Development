# %% [markdown]
# <a href="https://colab.research.google.com/github/Vathsav56/AI-Agents-Development/blob/main/code/TranslaterViaGgle.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install googletrans==4.0.0-rc1
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.1/55.1 kB 3.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.4/133.4 kB 5.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.6/42.6 kB 2.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 2.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.0/65.0 kB 3.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 23.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.6/53.6 kB 2.0 MB/s eta 0:00:00
# ...
#   Created wheel for googletrans: filename=googletrans-4.0.0rc1-py3-none-any.whl size=17396 sha256=249c502d73ed5a9f683f2eaafbf2f640fdce28c05396fe1773dd25d222d81f55
#   Stored in directory: /root/.cache/pip/wheels/39/17/6f/66a045ea3d168826074691b4b787b8f324d3f646d755443fda
# Successfully built googletrans
# ...
#   Attempting uninstall: hyperframe
#     Found existing installation: hyperframe 6.1.0
# ...

# %%
from googletrans import Translator
t = Translator()
text = input("Enter text :")
translated = t.translate(text,src='en', dest='te')
# Out:
# Enter text :hi all how are u doing

# %%
# prompt: what are differnt codes for diff launguages list indian launguages and foreigin seperate list as comments

# Indian languages:
# Hindi: hi
# Telugu: te
# Tamil: ta
# English: en
# Bengali: bn
# Gujarati: gu
# Kannada: kn
# Malayalam: ml
# Marathi: mr
# Nepali: ne
# Odia: or
# Punjabi: pa
# Sanskrit: sa
# Sindhi: sd
# Sinhalese: si
# Urdu: ur

# Foreign languages:
# Spanish: es
# French: fr
# German: de
# Japanese: ja
# Chinese: zh-cn
# Russian: ru
# Arabic: ar
# Portuguese: pt
# Italian: it
# Korean: ko
# Dutch: nl
# Swedish: sv
# Norwegian: no
# Danish: da
# Finnish: fi
# Greek: el
# Turkish: tr
# Vietnamese: vi
# Thai: th
# Indonesian: id
# Malay: ms
# Filipino: fil
# Czech: cs
# Slovak: sk
# Polish: pl
# Hungarian: hu
# Romanian: ro
# Bulgarian: bg
# Serbian: sr
# Croatian: hr
# Bosnian: bs
# Macedonian: mk
# Albanian: sq
# Lithuanian: lt
# Latvian: lv
# Estonian: et
# Icelandic: is
# Georgian: ka
# Armenian: hy
# Azerbaijani: az
# Kyrgyz: ky
# Kazakh: kk
# Uzbek: uz
# Tajik: tg
# Turkmen: tk
# Uyghur: ug
# Mongolian: mn
# Pashto: ps
# Dari: prs
# Kurdish: ku
# Somali: so
# Swahili: sw
# Amharic: am
# Igbo: ig
# Yoruba: yo
# Hausa: ha
# Zulu: zu
# Xhosa: xh
# Afrikaans: af
# Sesotho: st
# Northern Sotho: nso
# Tswana: tn
# Venda: ve
# Tsonga: ts
# Swati: ss
# Rundi: rn
# Kinyarwanda: rw
# Lingala: ln
# Kongo: kg
# Kikuyu: ki
# Ganda: lg
# Ewe: ee
# Akan: ak
# Fula: ff
# Malagasy: mg
# Maori: mi
# Samoan: sm
# Tongan: to
# Fijian: fj
# Tahitian: ty
# Hawaiian: haw
# Maltese: mt
# Hebrew: iw (or he)
# Yiddish: yi
# Luxembourgish: lb
# Frisian: fy
# Irish: ga
# Scottish Gaelic: gd
# Welsh: cy
# Basque: eu
# Catalan: ca
# Galician: gl
# Esperanto: eo
# Ido: io
# Volapük: vo
# Interlingua: ia
# Occitan: oc
# Breton: br
# Cornish: kw
# Manx: gv
# Romansh: rm
# Friulian: fur
# Ladin: ldn
# Sardinian: sc
# Neapolitan: nap
# Sicilian: scn
# Piedmontese: pms
# Venetian: vec
# Ligurian: lij
# Lombard: lmo
# Emilian: eml
# Romagnol: rgn
# Corsican: co
# Bosnian: bs
# Montenegrin: cnr
# Serbian: sr
# Croatian: hr
# Slovenian: sl
# Macedonian: mk
# Bulgarian: bg
# Ukrainian: uk
# Belarusian: be
# Russian: ru
# Polish: pl
# Czech: cs
# Slovak: sk
# Hungarian: hu
# Romanian: ro
# Moldavian: mo
# Albanian: sq
# Greek: el
# Turkish: tr
# Azerbaijani: az
# Georgian: ka
# Armenian: hy
# Estonian: et
# Latvian: lv
# Lithuanian: lt
# Finnish: fi
# Swedish: sv
# Norwegian: no
# Danish: da
# Icelandic: is
# Faroese: fo
# Dutch: nl
# Afrikaans: af
# Frisian: fy
# German: de
# Luxembourgish: lb
# Yiddish: yi
# English: en
# French: fr
# Spanish: es
# Portuguese: pt
# Italian: it
# Catalan: ca
# Galician: gl
# Basque: eu
# Irish: ga
# Scottish Gaelic: gd
# Welsh: cy
# Breton: br
# Cornish: kw
# Manx: gv
# Maltese: mt
# Hebrew: iw (or he)
# Arabic: ar
# Syriac: syr
# Aramaic: arc
# Samaritan Aramaic: sam
# Mandaic: myt
# Ethiopian: et
# Amharic: am
# Tigrinya: ti
# Gurage: guz
# Somali: so
# Oromo: om
# Swahili: sw
# Ganda: lg
# Kinyarwanda: rw
# Rundi: rn
# Lingala: ln
# Kongo: kg
# Kikuyu: ki
# Ewe: ee
# Akan: ak
# Fula: ff
# Yoruba: yo
# Igbo: ig
# Hausa: ha
# Zulu: zu
# Xhosa: xh
# Sesotho: st
# Northern Sotho: nso
# Tswana: tn
# Venda: ve
# Tsonga: ts
# Swati: ss
# Malagasy: mg
# Comorian: swb
# Seychellois Creole: crs
# Mauritian Creole: mfe
# Reunion Creole: rcf
# Haitian Creole: ht
# Jamaican Patois: jam
# Tok Pisin: tpi
# Hiri Motu: hmo
# Bislama: bis
# Pijin: pgn
# Solomon Islands Pijin: pis
# Torres Strait Creole: tcs
# Kriol: kri
# Norfuk: nrf
# Pitcairn-Norfolk: pih
# Sranan Tongo: srn
# Saramaccan: srm
# Ndyuka: djk
# Kwinti: kww
# Haitian Creole: ht
# Mauritian Creole: mfe
# Reunion Creole: rcf
# Seychellois Creole: crs
# Malagasy: mg
# Comorian: swb
# Swahili: sw
# Ganda: lg
# Kinyarwanda: rw
# Rundi: rn
# Lingala: ln
# Kongo: kg
# Kikuyu: ki
# Ewe: ee
# Akan: ak
# Fula: ff
# Yoruba: yo
# Igbo: ig
# Hausa: ha
# Zulu: zu
# Xhosa: xh
# Sesotho: st
# Northern Sotho: nso
# Tswana: tn
# Venda: ve
# Tsonga: ts
# Swati: ss
# Somali: so
# Oromo: om
# Amharic: am
# Tigrinya: ti
# Gurage: guz
# Arabic: ar
# Syriac: syr
# Aramaic: arc
# Samaritan Aramaic: sam
# Mandaic: myt
# Hebrew: iw (or he)
# Yiddish: yi
# Maltese: mt
# Georgian: ka
# Armenian: hy
# Azerbaijani: az
# Ossetian: os
# Chechen: ce
# Ingush: inh
# Lezghian: lez
# Avar: ava
# Dargwa: dar
# Lak: lah
# Tabassaran: tab
# Rutul: rut
# Tsakhur: tsk
# Kryts: krc
# Budukh: bdk
# Udi: udi
# Khinalug: kjh
# Bezhta: bez
# Hunzib: hnz
# Botlikh: bph
# Godoberi: gob
# Karata: kpt
# Bagvalal: bgr
# Tindi: tin
# Chamalal: cml
# Gigitli: ggi
# Andi: ani
# Akhvakh: akh
# Tsez: tsez
# Khwarshi: khw
# Hinukh: hinu
# Bezhta: bez
# Hunzib: hnz
# Botlikh: bph
# Godoberi: gob
# Karata: kpt
# Bagvalal: bgr
# Tindi: tin
# Chamalal: cml
# Gigitli: ggi
# Andi: ani
# Akhvakh: akh
# Tsez: tsez
# Khwarshi: khw
# Hinukh: hinu
# Abaza: abz
# Abkhazian: ab
# Adyghe: ady
# Kabardian: kbd
# Ubykh: uby
# Circassian: cir
# Basque: eu
# Georgian: ka
# Armenian: hy
# Azerbaijani: az
# Nakh: nah
# Vainakh: vai
# Chechen: ce
# Ingush: inh
# Avar: ava
# Andi: ani
# Bagvalal: bgr
# Botlikh: bph
# Chamalal: cml
# Godoberi: gob
# Karata: kpt
# Tindi: tin
# Akhvakh: akh
# Tsez: tsez
# Khwarshi: khw
# Hinukh: hinu
# Bezhta: bez
# Hunzib: hnz
# Lak: lah
# Dargwa: dar
# Lezghian: lez
# Tabassaran: tab
# Rutul: rut
# Tsakhur: tsk
# Kryts: krc
# Budukh: bdk
# Udi: udi
# Khinalug: kjh
# Abaza: abz
# Abkhazian: ab
# Adyghe: ady
# Kabardian: kbd
# Ubykh: uby
# Circassian: cir
# Indo-European languages
# Romance languages
# Italian: it
# French: fr
# Spanish: es
# Portuguese: pt
# Catalan: ca
# Galician: gl
# Romanian: ro
# Moldavian: mo
# Occitan: oc
# Provençal: pro
# Franco-Provençal: frp
# Walloon: wa
# Picard: pic
# Norman: norm
# Gallo: gal
# Poitevin-Saintongeais: poitou
# Champenois: ch
# Lorrain: lorr
# Bourguignon-Morvandiau: bourg
# Franc-Comtois: frc
# Picard: pic
# Walloon: wa
# Lorrain: lorr
# Champenois: ch
# Norman: norm
# Gallo: gal
# Poitevin-Saintongeais: poitou
# Bourguignon-Morvandiau: bourg
# Franc-Comtois: frc
# Arpitan: frp
# Friulian: fur
# Ladin: ldn
# Sardinian: sc
# Neapolitan: nap
# Sicilian: scn
# Piedmontese: pms
# Ligurian: lij
# Lombard: lmo
# Emilian: eml
# Romagnol: rgn
# Venetian: vec
# Corsican: co
# Slavic languages
# East Slavic languages
# Russian: ru
# Ukrainian: uk
# Belarusian: be
# Rusyn: rue
# West Slavic languages
# Polish: pl
# Czech: cs
# Slovak: sk
# Sorbian: wen (lower)
# Sorbian: hsb (upper)
# Kashubian: csb
# Silesian: szl
# South Slavic languages
# Serbo-Croatian: hbs (macrolanguage)
# Bosnian: bs
# Croatian: hr
# Serbian: sr
# Montenegrin: cnr
# Slovenian: sl
# Macedonian: mk
# Bulgarian: bg
# Germanic languages
# West Germanic languages
# English: en
# German: de
# Dutch: nl
# Afrikaans: af
# Frisian: fy
# Flemish: vls
# Limburgish: li
# Ripuarian: ksh
# Moselle Franconian: mom
# Palatinate German: pfl
# Hessian: hes
# Thuringian: thg
# Upper Saxon: sxu
# Silesian German: sli
# Low German: nds
# Low Rhenish: wep
# Northern German: frr (northern Frisian)
# Saterland Frisian: stq
# Eastern Frisian: frs
# North Germanic languages
# Swedish: sv
# Danish: da
# Norwegian: no (nor)
# Norwegian Bokmål: nb
# Norwegian Nynorsk: nn
# Icelandic: is
# Faroese: fo
# Gutnish: gmq
# Celtic languages
# Goidelic languages
# Irish: ga
# Scottish Gaelic: gd
# Manx: gv
# Brittonic languages
# Welsh: cy
# Cornish: kw
# Breton: br
# Baltic languages
# Lithuanian: lt
# Latvian: lv
# Old Prussian: pru
# Slavic languages
# East Slavic languages
# Russian: ru
# Ukrainian: uk
# Belarusian: be
# Rusyn: rue
# West Slavic languages
# Polish: pl
# Czech: cs
# Slovak: sk
# Sorbian: wen (lower)
# Sorbian: hsb (upper)
# Kashubian: csb
# Silesian: szl
# South Slavic languages
# Serbo-Croatian: hbs (macrolanguage)
# Bosnian: bs
# Croatian: hr
# Serbian: sr
# Montenegrin: cnr
# Slovenian: sl
# Macedonian: mk
# Bulgarian: bg
# Albanian: sq
# Greek: el
# Armenian: hy
# Indo-Aryan languages (Indian languages)
# Hindi: hi
# Urdu: ur
# Bengali: bn
# Marathi: mr
# Punjabi: pa
# Gujarati: gu
# Rajasthani: raj
# Marwari: mwr
# Mewari: mew
# Harauti: hao
# Malvi: mly
# Nimadi: bgc
# Bagri: bgc
# Dhundhari: dhd
# Haryanvi: bgc
# Braj Bhasha: bra
# Kannauji: bjj
# Awadhi: awa
# Bagheli: bgl
# Chhattisgarhi: hne
# Bhojpuri: bho
# Magahi: mag
# Maithili: mai
# Angika: anp
# Bajjika: bjd
# Nagpuria: nag
# Khortha: kjh
# Kurmali: kfy
# Panchpargania: pgr
# Sadri: sck
# Odisha: or
# Assamese: as
# Bengali: bn
# Bishnupriya Manipuri: bpy
# Chakma: ccp
# Chittagonian: ctg
# Hajong: haj
# Karbi: mjw
# Kokborok: trp
# Kurukh: kru
# Sadri: sck
# Sylheti: syl
# Tanchangya: tny
# Tippera: trp
# Meitei (Manipuri): mni
# Malayalam: ml
# Kannada: kn
# Tamil: ta
# Telugu: te
# Tulu: tcy
# Konkani: kok
# Marathi: mr
# Gujarati: gu
# Sindhi: sd
# Nepali: ne
# Sinhalese: si
# Divehi: div
# Romani: rom
# Iranian languages
# Persian: fa
# Tajik: tg
# Dari: prs
# Pashto: ps
# Kurdish: ku
# Balochi: bal
# Ossetian: os
# Yazghulami: yah
# Shughni: sgh
# Rushani: ruc
# Oroshor: ors
# Bartangi: bgj
# Roshorvi: rsh
# Khufi: khf
# Ishkashimi: isk
# Wakhi: wbl
# Sarikoli: srh
# Yazgulyam: yah
# Sanglechi: sgl
# Zebaki: zeb
# Ormuri: orm
# Parachi: prc
# Kumzari: zum
# Larestani: lrl
# Bashkardi: bsh
# Minabi: mnb
# Hormozi: horm
# Bandari: bdn
# Bastaki: btk
# Kumzari: zum
# Tat: tat
# Judeo-Tat: jpr
# Talysh: tly
# Gilaki: glk
# Mazanderani: mzn
# Semnani: smn
# Sangisari: sgr
# Lasgerdi: lsa
# Sorkhei: sqo
# Dezfuli: dfi
# Shushtari: shus
# Luri: lur
# Bakhtiari: bkh
# Feyli: fae
# Kumzari: zum
# Brahui: brs
# Dravidian languages (Indian languages)
# Tamil: ta
# Telugu: te
# Kannada: kn
# Malayalam: ml
# Tulu: tcy
# Konkani: kok
# Brahui: brs
# Gondi: gon
# Konda: kfc
# Kui: kxu
# Kuvi: kxv
# Manda: mha
# Pengo: pag
# Toda: toda1238
# Kota: kfe
# Koraga: kfq
# Kurumba: kfi
# Mala Malasar: mup
# Urali: url
# Yerukula: yru
# Turkic languages
# Turkish: tr
# Azerbaijani: az
# Turkmen: tk
# Uyghur: ug
# Uzbek: uz
# Kazakh: kk
# Kyrgyz: ky
# Tatar: tt
# Bashkir: ba
# Chuvash: cv
# Yakut: sah
# Tuvan: tyv
# Shor: shr
# Khakas: kkk
# Altai: alt
# Tofa: tof
# Soyot-Tsagaan: say
# Chulym: chu
# Kumyk: kum
# Karachay-Balkar: krc
# Nogai: nog
# Karakalpak: kaa
# Crimean Tatar: crh
# Krymchak: krm
# Urum: uum
# Gagauz: gag
# Balkan Gagauz Turkish: bgx
# Kipchak languages
# Crimean Tatar: crh
# Kumyk: kum
# Karachay-Balkar: krc
# Nogai: nog
# Karakalpak: kaa
# Kipchak-Uzbek: qyp
# Siberian Turkic languages
# Altai: alt
# Shor: shr
# Khakas: kkk
# Tuvan: tyv
# Tofa: tof
# Soyot-Tsagaan: say
# Chulym: chu
# Oghuz languages
# Turkish: tr
# Azerbaijani: az
# Turkmen: tk
# Qashqai: qxq
# Khorasani Turkic: khr
# Salar: slr
# Gagauz: gag
# Balkan Gagauz Turkish: bgx
# Oghuz-Turkmen: ogu
# Karluk languages
# Uzbek: uz
# Uyghur: ug
# Ili Turki: ili
# Chagatay: chg
# Mongolic languages
# Mongolian: mn
# Buryat: bua
# Kalmyk: xal
# Oirat: xal
# Monguor: mjg
# Dongxiang: dox
# Bonan: bnp
# Tibetan languages
# Tibetan: bo
# Dzongkha: dz
# Ladakhi: lbj
# Balti: bcl
# Sherpa: sre
# सिक्किमी: sip
# Tamang: rej
# Gurung: gvr
# Newar: new
# Magar: mgr
# Rai languages: bhj
# Limbu: lif
# Sunwar: suw
# Jirel: jir
# Thulung: thl
# Kulung: kly
# Khaling: kli
# Dumi: dup
# Kohistani: khs
# Shina: sii
# Brokskat: bsk
# Kashmiri: ks
# Shina: sii
# Kohistani: khs
# Indus Kohistani: iks
# Palasi: pls
# Manthali: mth
# Chiliss: clh
# Gowro: gwf
# Battagram Kohistani: btk
# Kalami: gwc
# Torwali: trw
# Indus Kohistani: iks
# Palasi: pls
# Manthali: mth
# Chiliss: clh
# Gowro: gwf
# Battagram Kohistani: btk
# Kalami: gwc
# Torwali: trw
# Burushaski: bsk
# Wakhi: wbl
# Ishkashimi: isk
# Sanglechi: sgl
# Zebaki: zeb
# Sarikoli: srh
# Shughni: sgh
# Rushani: ruc
# Oroshor: ors
# Bartangi: bgj
# Roshorvi: rsh
# Khufi: khf
# Yazgulyam: yah
# Ormuri: orm
# Parachi: prc
# Kumzari: zum
# Larestani: lrl
# Bashkardi: bsh
# Minabi: mnb
# Hormozi: horm
# Bandari: bdn
# Bastaki: btk
# Kumzari: zum
# Uralic languages
# Finnic languages
# Finnish: fi
# Estonian: et
# Karelian: krl
# Veps: vep
# Izhorian: izh
# Votic: vot
# Livonian: liv
# Sami languages
# Northern Sami: se
# Lule Sami: smj
# Pite Sami: sjp
# Ume Sami: smu
# Southern Sami: sma
# Skolt Sami: sms
# Inari Sami: smn
# Kildin Sami: sjd
# Eastern Sami languages
# Erzya: myv
# Moksha: mdf
# Udmurt: udm
# Komi-Zyryan: kpv
# Komi-Permyak: koi
# Mari: mhr (hill), mrj (meadow)
# Mordvin languages: mdf (Moksha), myv (Erzya)
# Permic languages: koi (Komi-Permyak), kpv (Komi-Zyryan), udm (Udmurt)
# Samoyedic languages
# Nenets: nje
# Enets: enf
# Nganasan: nio
# Selkup: sel
# Kamass: kma
# Mator: mtr
# Hungarian: hu
# Yeniseian languages
# Ket: ket
# Yugh: yug
# Chukotko-Kamchatkan languages
# Chukot: ckt
# Koryak: kpy
# Alyutor: alr
# Kerek: krk
# Itelmen: itl
# Eskimo-Aleut languages
# Eskimo languages
# Inuit languages
# Inuktitut: ik
# Greenlandic: kl
# Inupiaq: ipk
# Inuvialuktun: ikt
# Yupik languages
# Central Yupik: yup
# Alutiiq: alw
# Siberian Yupik: ess
# Sirenik Yupik: ysj
# Aleut: ale
# Japanese: ja
# Korean: ko
# Ainu: ain
# Nivkh: niv
# Itelmen: itl
# Yeniseian languages
# Ket: ket
# Yugh: yug
# Chukotko-Kamchatkan languages
# Chukot: ckt
# Koryak: kpy
# Alyutor: alr
# Kerek: krk
# Itelmen: itl
# Eskimo-Aleut languages
# Eskimo languages
# Inuit languages
# Inuktitut: ik
# Greenlandic: kl
# Inupiaq: ipk
# Inuvialuktun: ikt
# Yupik languages
# Central Yupik: yup
# Alutiiq: alw
# Siberian Yupik: ess
# Sirenik Yupik: ysj
# Aleut: ale
# Tai-Kadai languages
# Thai: th
# Lao: lo
# Shan: shn
# Zhuang: za
# Bouyei: pcc
# Tay: tyz
# Nung: nng
# Tho: tho
# Chinese: zh (zho)
# Mandarin Chinese: cmn
# Cantonese Chinese: yue
# Wu Chinese: wuu
# Gan Chinese: gan
# Hakka Chinese: hak
# Min Chinese: zh-min (macrolanguage)
# Min Dong Chinese: czo
# Min Nan Chinese: nan
# Hokkien: nan
# Taiwanese: nan
# Teochew: nan
# Min Bei Chinese: mnw
# Min Zhong Chinese: czu
# Pu-Xian Chinese: cpx
# Xiang Chinese: hsn
# Austronesian languages
# Malayo-Polynesian languages
# Malay: ms
# Indonesian: id
# Javanese: jv
# Sundanese: su
# Madurese: mad
# Balinese: ban
# Sasak: sas
# Sumbawa: smw
# Moken: mhn
# Moklen: mqt
# Urak Lawoi': urk
# Rejang: rej
# Lampung: ljp
# Acehnese: ace
# Minangkabau: min
# Banjarese: bjn
# Iban: iba
# Bidayuh: bzd
# Melanau: mel
# Kadazan Dusun: kzt
# Murutic languages: mru
# Paitanic languages: ptn
# Sama-Bajau languages: bts
# Sulawesi languages: sul
# Philippine languages: phi (macrolanguage)
# Tagalog: tl
# Filipino: fil
# Cebuano: ceb
# Hiligaynon: hil
# Waray-Waray: war
# Bikol languages: bik
# Ilocano: ilo
# Pangasinan: pag
# Kapampangan: pam
# Maguindanao: mdh
# Maranao: mrw
# Tausug: tsg
# Chavacano: cbk
# Hawaiian: haw
# Maori: mi
# Samoan: sm
# Tongan: to
# Fijian: fj
# Tahitian: ty
# Marquesan: mqm
# Tuamotuan: pmq
# Rapa Nui: rap
# Rarotongan: rar
# Cook Islands Maori: rar
# Austronesian languages
# Formosan languages
# Paiwan: pwn
# Bunun: bnn
# Atayal: tay
# Amis: ami
# Kavalan: kzn
# Saaroa: sxr
# Kanakanavu: xnb
# Puyuma: pyu
# Tsou: tsu
# Rukai: rkt
# Saisiyat: say
# Thao: trq
# Ketagalan: ktl
# Basay: byq
# Luilang: lwg
# Favorlang: fvlg
# Babuza: bzg
# Taokas: tao
# Pazeh: pze
# Siraya: fos
# Makatao: mcp
# Austronesian languages
# Malayo-Polynesian languages
# Malay: ms
# Indonesian: id
# Javanese: jv
# Sundanese: su
# Madurese: mad
# Balinese: ban
# Sasak: sas
# Sumbawa: smw
# Moken: mhn
# Moklen: mqt
# Urak Lawoi': urk
# Rejang: rej
# Lampung: ljp
# Acehnese: ace
# Minangkabau: min
# Banjarese: bjn
# Iban: iba
# Bidayuh: bzd
# Melanau: mel
# Kadazan Dusun: kzt
# Murutic languages: mru
# Paitanic languages: ptn
# Sama-Bajau languages: bts
# Sulawesi languages: sul
# Philippine languages: phi (macrolanguage)
# Tagalog: tl
# Filipino: fil
# Cebuano: ceb
# Hiligaynon: hil
# Waray-Waray: war
# Bikol languages: bik
# Ilocano: ilo
# Pangasinan: pag
# Kapampangan: pam
# Maguindanao: mdh
# Maranao: mrw
# Tausug: tsg
# Chavacano: cbk
# Oceanic languages
# Hawaiian: haw
# Maori: mi
# Samoan: sm
# Tongan: to
# Fijian: fj
# Tahitian: ty
# Marquesan: mqm
# Tuamotuan: pmq
# Rapa Nui: rap
# Rarotongan: rar
# Cook Islands Maori: rar
# Malagasy: mg
# Comorian: swb
# Seychellois Creole: crs
# Mauritian Creole: mfe
# Reunion Creole: rcf
# Papuan languages
# Trans–New Guinea languages
# Enga: ena
# Melpa: med
# Huli: huk
# Dani languages: dni (Upper), dnt (Lower), dno (Western)
# Lani: lni
# Etoro: uro
# Foi: foi
# Ide: ide
# Sau: sau
# Kewabi: kwv
# Mendi: meng
# Polari: plj
# Wiru: wir
# East Strickland languages: gbd
# Duna: dun
# Oksapmin: oks
# Telefol: tlf
# Oksapmin: oks
# Telefol: tlf
# Unlike languages: unlike
# Kwomtari languages: kwo
# Left May languages: lep
# Border languages: boi
# Torricelli languages: tej
# Sko languages: sko
# Sepik languages: spk
# Ramu languages: rmq
# Yuat languages: yuat
# Lower Sepik–Ramu languages: rmq
# Kwalean languages: kwl
# Fas languages: fas
# Pauwasi languages: pwf
# Amto-Musan languages: amt
# Bayono-Awbono languages: bwa
# Timor–Alor–Pantar languages: tag
# Alor: aol
# Pantar: pnt
# Teiwa: twa
# Wersing: wer
# Blagar: bhw
# Kamang: kmi
# Kui: kxu
# Kula: kula1242
# Abui: abz
# Adang: adg
# Hamap: hap
# Kabola: klz
# Kafoa: kfo
# Kolana: klr
# Komodo: kom
# Laowu: law
# Madar: mjr
# Maneta: mzn
# Muri: mur
# Retta: ret
# Sawila: swl
# Tewa: twe
# Watar: wat
# Lamaholot: lmg
# Adonara: adr
# Solor: sol
# Lewotobi: lwt
# Ili Ape: ilp
# Kedang: knb
# Sikka: skq
# Lio: lio
# Palu'e: ple
# Ende: end
# Manggarai: mgg
# Riung: rng
# Rembong: rem
# Waerebo: wrb
# West Manggarai: wea
# Bima: bhx
# Ngadha: ncd
# Nage: nre
# Keo: kke
# So'a: sqq
# Bajau: bdr
# Sasak: sas
# Sumbawa: smw
# Moken: mhn
# Moklen: mqt
# Urak Lawoi': urk
# Rejang: rej
# Lampung: ljp
# Acehnese: ace
# Minangkabau: min
# Banjarese: bjn
# Iban: iba
# Bidayuh: bzd
# Melanau: mel
# Kadazan Dusun: kzt
# Murutic languages: mru
# Paitanic languages: ptn
# Sama-Bajau languages: bts
# Sulawesi languages: sul
# Philippine languages: phi (macrolanguage)
# Tagalog: tl
# Filipino: fil
# Cebuano: ceb
# Hiligaynon: hil
# Waray-Waray: war
# Bikol languages: bik
# Ilocano: ilo
# Pangasinan: pag
# Kapampangan: pam
# Maguindanao: mdh
# Maranao: mrw
# Tausug: tsg
# Chavacano: cbk
# Oceanic languages
# Hawaiian: haw
# Maori: mi
# Samoan: sm
# Tongan: to
# Fijian: fj
# Tahitian: ty
# Marquesan: mqm
# Tuamotuan: pmq
# Rapa Nui: rap
# Rarotongan: rar
# Cook Islands Maori: rar
# Malagasy: mg
# Comorian: swb
# Seychellois Creole: crs
# Mauritian Creole: mfe
# Reunion Creole: rcf
# Australian Aboriginal languages
# Pama–Nyungan languages: pmn
# Arandic languages: are
# Southwestern Pama–Nyungan languages
# Wati languages: wati1241
# Western Desert Language: wga
# Pitjantjatjara: pjt
# Yankunytjatjara: yre
# Ngaanyatjarra: nga
# Kokatha: kkf
# Kukatja: kux
# Martu Wangka: mwr
# Mardu: zrd
# Yulparija: ylj
# Kartujarra: kcr
# Putijarra: ptz
# Warnman: wrn
# Nyiyaparli: nyp
# Kurrama: kri
# Mardidjali: mdz
# Ngarla: nrl
# Nyamal: nyl
# Yindjibarndi: yjb
# Ngarluma: nrl
# Kariyarra: kiy
# Martuthunira: mrt
# Thalanyji: thl
# Jiwarli: jia
# Panyjima: pnj
# Jurruru: jru
# Ngarawudu: nra
# Binigura: bnr
# Mandinya: wgr
# Tharrgari: thr
# Warriyangga: wrg
# Wadjari: wji
# Badimaya: bae
# Mullewa: mxj
# Wanmala: wml
# Wadjari: wji
# Badimaya: bae
# Mullewa: mxj
# Wanmala: wml
# Northern Pama–Nyungan languages
# Kalkatungu: klg
# Warlpiri: wbp
# Kaytetye: kty
# Warumungu: wrg
# Gurindji: grin1244
# Mudburra: mue
# Bilinara: bil
# Jingulu: jgl
# Ngarnga: nra
# Wadaman: wdn
# Wardaman: wdn
# Yangman: yng
# Lauraland languages: laul1237
# Gunwingguan languages: gunw1239
# Bininj Gun-wok: gup
# Maung: mbu
# Kunwinjku: gaw
# Gaagudju: ggu
# Giimbiyu: giy
# Kunbarlang: kuf
# Rembarunga: rmb
# Ngalakan: ngk
# Alawa: alw
# Marra: mea
# Warndarrang: wrr
# Yaegl: ygl
# Bandjalangic languages: bdy
# Bundjalung: bdy
# Gidabal: gib
# Yugambeh-Bundjalung: yug
# Yaygirr: ygr
# Kumbainggar: kgs
# Gumbaynggirr: kgs
# Wanarua: wro
# Wiradjuri: wrj
# Ngiyambaa: nge
# Gamilaraay: gld
# Yuwaalaraay: yul
# Yuwaaliyaay: yuj
# Bigambul: bhm
# Barunggam: bru
# Wakka Wakka: wkw
# Gubbi Gubbi: gub
# Butchulla: xbu
# Djabugay: djg
# Yidinj: yiy
# Dyirbal: dyr
# Girramay: gry
# Warrgamay: wrg
# Nyawaygi: nyw
# Mbabaram: mby
# Agusan: agus1234
# Bagobo: bgo
# Blaan: bpr
# Cebuano: ceb
# Cotabato Manobo: mbr
# Davao: dav
# Higaonon: hgn
# Hiligaynon: hil
# Bukidnon: bkd
# Butuanon: btn
# Cagayanen: cgc
# Kalagan: klm
# Kamayo: kye
# Kankanay: knb
# Karao: kto
# Kinabalian: kkb
# Kinamiging Manobo: mkx
# Maguindanao: mdh
# Mamanwa: mmy
# Mandaya: mdy
# Mansaka: mns
# Matigsalug Manobo: mtm
# Obo Manobo: mbo
# Sama-Bajau languages: bts
# Sindangan Subanon: sue
# Southern Catanduanes Bikol: bto
# Surigaonon: srg
# Tagabawa: tgw
# Tausug: tsg
# Tasaday: tsd
# Tboli: tbl
# Western Bukidnon Manobo: mbb
# Sama-Bajau languages: bts
# Abaknon: apk
# Yakan: yak
# Mapun: mmp
# Sama Dilaut: sdl
# Sama Southern: ssb
# Sama Central: sml
# Sama Pangutaran: snp
# Sama Sibutu: ssy
# Sama Tandubas: ssa
# Balangingi Sama: ssb
# Bajau West Coast: bts
# Bajau Indonesian: bdj
# Bajau Laut: bts
# Philippine languages: phi (macrolanguage)
# Tagalog: tl
# Filipino: fil
# Cebuano: ceb
# Hiligaynon: hil
# Waray-Waray: war
# Bikol languages: bik
# Ilocano: ilo
# Pangasinan: pag
# Kapampangan: pam
# Maguindanao: mdh
# Maranao: mrw
# Tausug: tsg
# Chavacano: cbk
# Austronesian languages
# Formosan languages
# Paiwan: pwn
# Bunun: bnn
# Atayal: tay
# Amis: ami
# Kavalan: kzn
# Saaroa: sxr
# Kanakanavu: xnb
# Puyuma: pyu
# Tsou: tsu
# Rukai: rkt
# Saisiyat: say
# Thao: trq
# Ketagalan: ktl
# Basay: byq
# Luilang: lwg
# Favorlang: fvlg
# Babuza: bzg
# Taokas: tao
# Pazeh: pze
# Siraya: fos
# Makatao: mcp
# Tai-Kadai languages
# Thai: th
# Lao: lo
# Shan: shn
# Zhuang: za
# Bouyei: pcc
# Tay: tyz
# Nung: nng
# Tho: tho
# Miao-Yao languages
# Hmong: hmn (hmo)
# Hmong Daw: mww
# Hmong Njua: hnj
# Miao: hmo
# Bunu: bnu
# Mien: ium
# Mien: jud
# Vietnamese: vi
# Khmer: km
# Mon: mnw
# Austroasiatic languages
# Mon-Khmer languages
# Khmer: km
# Mon: mnw
# Palaungic languages: pla
# Wa: wbm
# Eastern Tai languages
# Lao: lo
# Thai: th
# Shan: shn
# Tai Dam: blt
# Tai Lu: tjv
# Tai Nua: tdd
# Tai Phake: phk
# Tai Ruea: trc
# Tai Yuan: Northern Thai: nod
# Ahom: aho
# Southern Tai languages
# Southern Thai: sou
# Malayic languages
# Malay: ms
# Indonesian: id
# Minangkabau: min
# Banjarese: bjn
# Iban: iba
# Betawi: bew
# Brunei Malay: kxd
# Jakartan Malay: mly
# Kedah Malay: meo
# Malay (individual language): zlm
# Pattani Malay: mfa
# Tenggarong Malay: teng1238
# Singapore Malay: mly
# Standard Malay: zsm
# Javanese: jv
# Sundanese: su
# Madurese: mad
# Balinese: ban
# Sasak: sas
# Sumbawa: smw
# Moken: mhn
# Moklen: mqt
# Urak Lawoi': urk
# Rejang: rej
# Lampung: ljp
# Acehnese: ace
# Philippine languages: phi (macrolanguage)
# Tagalog: tl
# Filipino: fil
# Cebuano: ceb
# Hiligaynon: hil
# Waray-Waray: war
# Bikol languages: bik
# Ilocano: ilo
# Pangasinan: pag
# Kapampangan: pam
# Maguindanao: mdh
# Maranao: mrw
# Tausug: tsg
# Chavacano: cbk
# Oceanic languages
# Hawaiian: haw
# Maori: mi
# Samoan: sm
# Tongan: to
# Fijian: fj
# Tahitian: ty
# Marquesan: mqm
# Tuamotuan: pmq
# Rapa Nui: rap
# Rarotongan: rar
# Cook Islands Maori: rar
# Malagasy: mg
# Comorian: swb
# Seychellois Creole: crs
# Mauritian Creole: mfe
# Reunion Creole: rcf
# Papuan languages
# Trans–New Guinea languages
# Enga: ena
# Melpa: med
# Huli: huk
# Dani languages: dni (Upper), dnt (Lower), dno (Western)
# Lani: lni
# Etoro: uro
# Foi: foi
# Ide: ide
# Sau: sau
# Kewabi: kwv
# Mendi: meng
# Polari: plj
# Wiru: wir
# East Strickland languages: gbd
# Duna: dun
# Oksapmin: oks
# Telefol: tlf
# Oksapmin: oks
# Telefol: tlf
# Unlike languages: unlike
# Kwomtari languages: kwo
# Left May languages: lep
# Border languages: boi
# Torricelli languages: tej
# Sko languages: sko
# Sepik languages: spk
# Ramu languages: rmq
# Yuat languages: yuat
# Lower Sepik–Ramu languages: rmq
# Kwalean languages: kwl
# Fas languages: fas
# Pauwasi languages: pwf
# Amto-Musan languages: amt
# Bayono-Awbono languages: bwa
# Timor–Alor–Pantar languages: tag
# Alor: aol
# Pantar: pnt
# Teiwa: twa
# Wersing: wer
# Blagar: bhw
# Kamang: kmi
# Kui: kxu
# Kula: kula1242
# Abui: abz
# Adang: adg
# Hamap: hap
# Kabola: klz
# Kafoa: kfo
# Kolana: klr
# Komodo: kom
# Laowu: law
# Madar: mjr
# Maneta: mzn
# Muri: mur
# Retta: ret
# Sawila: swl
# Tewa: twe
# Watar: wat
# Lamaholot: lmg
# Adonara: adr
# Solor: sol
# Lewotobi: lwt
# Ili Ape: ilp
# Kedang: knb
# Sikka: skq
# Lio: lio
# Palu'e: ple
# Ende: end
# Manggarai: mgg
# Riung: rng
# Rembong: rem
# Waerebo: wrb
# West Manggarai: wea
# Bima: bhx
# Ngadha: ncd
# Nage: nre
# Keo: kke
# So'a: sqq
# Bajau: bdr
# Sasak: sas
# Sumbawa: smw
# Moken: mhn
# Moklen: mqt
# Urak Lawoi': urk
# Rejang: rej
# Lampung: ljp
# Acehnese: ace
# Minangkabau: min
# Banjarese: bjn
# Iban: iba
# Bidayuh: bzd
# Melanau: mel
# Kadazan Dusun: kzt
# Murutic languages: mru
# Paitanic languages: ptn
# Sama-Bajau languages: bts
# Sulawesi languages: sul
# Philippine languages: phi (macrolanguage)
# Tagalog: tl
# Filipino: fil
# Cebuano: ceb
# Hiligaynon: hil
# Waray-Waray: war
# Bikol languages: bik
# Ilocano: ilo
# Pangasinan: pag
# Kapampangan: pam
# Maguindanao: mdh
# Maranao: mrw
# Tausug: tsg
# Chavacano: cbk
# Austronesian languages
# Formosan languages
# Paiwan: pwn
# Bunun: bnn
# Atayal: tay
# Amis: ami
# Kavalan: kzn
# Saaroa: sxr
# Kanakanavu: xnb
# Puyuma: pyu
# Tsou: tsu
# Rukai: rkt
# Saisiyat: say
# Thao: trq
# Ketagalan: ktl
# Basay: byq
# Luilang: lwg
# Favorlang: fvlg
# Babuza: bzg
# Taokas: tao
# Pazeh: pze
# Siraya: fos
# Makatao: mcp
# Tai-Kadai languages
# Thai: th
# Lao: lo
# Shan: shn
# Zhuang: za
# Bouyei: pcc
# Tay: tyz
# Nung: nng
# Tho: tho
# Miao-Yao languages
# Hmong: hmn (hmo)
# Hmong Daw: mww
# Hmong Njua: hnj
# Miao: hmo
# Bunu: bnu
# Mien: ium
# Mien: jud
# Vietnamese: vi
# Khmer: km
# Mon: mnw
# Austroasiatic languages
# Mon-Khmer languages
# Khmer: km
# Mon: mnw
# Palaungic languages: pla
# Wa: wbm
# Eastern Tai languages
# Lao: lo
# Thai: th
# Shan: shn
# Tai Dam: blt
# Tai Lu: tjv
# Tai Nua: tdd
# Tai Phake: phk
# Tai Ruea: trc
# Tai Yuan: Northern Thai: nod
# Ahom: aho
# Southern Tai languages
# Southern Thai: sou
# Malayic languages
# Malay: ms
# Indonesian: id
# Minangkabau: min
# Banjarese: bjn
# Iban: iba
# Betawi: bew
# Brunei Malay: kxd
# Jakartan Malay: mly
# Kedah Malay: meo
# Malay (individual language): zlm
# Pattani Malay: mfa
# Tenggarong Malay: teng1238
# Singapore Malay: mly
# Standard Malay: zsm
# Javanese: jv
# Sundanese: su
# Madurese: mad
# Balinese: ban
# Sasak: sas
# Sumbawa: smw
# Moken: mhn
# Moklen: mqt
# Urak Lawoi': urk
# Rejang: rej
# Lampung: ljp
# Acehnese: ace
# Philippine languages: phi (macrolanguage)
# Tagalog: tl
# Filipino: fil
# Cebuano: ceb
# Hiligaynon: hil
# Waray-Waray: war
# Bikol languages: bik
# Ilocano: ilo
# Pangasinan: pag
# Kapampangan: pam
# Maguindanao: mdh
# Maranao: mrw
# Tausug: tsg
# Chavacano: cbk
# Oceanic languages
# Hawaiian: haw
# Maori: mi
# Samoan: sm
# Tongan: to
# Fijian: fj
# Tahitian: ty
# Marquesan: mqm
# Tuamotuan: pmq
# Rapa Nui: rap
# Rarotongan: rar
# Cook Islands Maori: rar
# Malagasy: mg
# Comorian: swb
# Seychellois Creole: crs
# Mauritian Creole: mfe
# Reunion Creole: rcf

# This is not an exhaustive list, but covers many common languages.
# You can find a more complete list of language codes in ISO 639-1 or ISO 639-2.
# For googletrans specifically, you can find supported languages in the library's documentation or by inspecting the Translator object.

from googletrans import Translator
# !pip install googletrans==4.0.0-rc1

t = Translator()
text = input("Enter text :")
# Example translation to Hindi
translated = t.translate(text,src='en', dest='hi')
print(translated.text)

# Example translation to German (Foreign)
translated = t.translate(text,src='en', dest='de')
print(f"German translation: {translated.text}")

# Example translation to Tamil (Indian)
translated = t.translate(text,src='en', dest='ta')
print(f"Tamil translation: {translated.text}")
